# %%
#to load data and get information with brief
import pandas as pd
from matplotlib import pyplot
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataframe = pd.read_csv('daily-total-female-births-CA.csv', header=0)

# %%
dataframe.head()
# Out:
#          date  births
# 0  1959-01-01      35
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44

# %%
dataframe['date'].dtype
# Out:
# dtype('O')

# %%
df2 = pd.read_csv('daily-total-female-births-CA.csv', header=0, parse_dates=[0])

# %%
df2.head()
# Out:
#         date  births
# 0 1959-01-01      35
# 1 1959-01-02      32
# 2 1959-01-03      30
# 3 1959-01-04      31
# 4 1959-01-05      44

# %%
df2['births'].plot()

# %%
#<m8 is for date time format

# %%
#loading data as a series, first col is for data

series = pd.read_csv('daily-total-female-births-CA.csv', header=0, parse_dates=[0], index_col=0, squeeze=True)

# %%
series.head()
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# Name: births, dtype: int64

# %%
series.plot()

pyplot.show()



#exploring date and time - size of dataframe


series.shape
#shape is sttribute
# Out:
# (365,)

# %%
df2.shape

# %%
dataframe.shape
# Out:
# (365, 2)

# %%
#getting subset of data set

print(series['1959-01'])
# Out:
# date
# 1959-01-01    35
# 1959-01-02    32
# 1959-01-03    30
# 1959-01-04    31
# 1959-01-05    44
# 1959-01-06    29
# 1959-01-07    45
# 1959-01-08    43
# 1959-01-09    38
# 1959-01-10    27
# 1959-01-11    38
# 1959-01-12    33
# 1959-01-13    55
# 1959-01-14    47
# 1959-01-15    45
# 1959-01-16    37
# 1959-01-17    50
# 1959-01-18    43
# 1959-01-19    41
# 1959-01-20    52
# 1959-01-21    34
# 1959-01-22    53
# 1959-01-23    39
# 1959-01-24    32
# 1959-01-25    37
# 1959-01-26    43
# 1959-01-27    39
# 1959-01-28    35
# 1959-01-29    44
# 1959-01-30    38
# 1959-01-31    24
# Name: births, dtype: int64

# %%
df2[(df2['date'] > '1959-01-01') & (df2['date'] < '1959-01-21')]
# Out:
#          date  births
# 1  1959-01-02      32
# 2  1959-01-03      30
# 3  1959-01-04      31
# 4  1959-01-05      44
# 5  1959-01-06      29
# 6  1959-01-07      45
# 7  1959-01-08      43
# 8  1959-01-09      38
# 9  1959-01-10      27
# 10 1959-01-11      38
# 11 1959-01-12      33
# 12 1959-01-13      55
# 13 1959-01-14      47
# 14 1959-01-15      45
# 15 1959-01-16      37
# 16 1959-01-17      50
# 17 1959-01-18      43
# 18 1959-01-19      41
# 19 1959-01-20      52

# %%
#describemethod
#series.describe()

df2
# Out:
#           date  births
# 0   1959-01-01      35
# 1   1959-01-02      32
# 2   1959-01-03      30
# 3   1959-01-04      31
# 4   1959-01-05      44
# ..         ...     ...
# 360 1959-12-27      37
# 361 1959-12-28      52
# 362 1959-12-29      48
# 363 1959-12-30      55
# 364 1959-12-31      50
#
# [365 rows x 2 columns]

# %%
#df2.describe()

df2['births'].plot()

# %%
sns.regplot(x=df2.index.values, y=df2['births'])

# %%
sns.regplot(x=df2.index.values, y=df2['births'], order=2)

# %%
df3 = pd.read_csv('daily-min-temperatures.csv', header=0, parse_dates=[0])

# %%
df3.head()
# Out:
#         Date  Temp
# 0 1981-01-01  20.7
# 1 1981-01-02  17.9
# 2 1981-01-03  18.8
# 3 1981-01-04  14.6
# 4 1981-01-05  15.8

# %%
df3['Temp'].plot()

# %%
sns.regplot(x=df3.index.values, y=df3['Temp'])

# %%
#removing seasonality
df3
# Out:
#            Date  Temp
# 0    1981-01-01  20.7
# 1    1981-01-02  17.9
# 2    1981-01-03  18.8
# 3    1981-01-04  14.6
# 4    1981-01-05  15.8
# ...         ...   ...
# 3645 1990-12-27  14.0
# 3646 1990-12-28  13.6
# 3647 1990-12-29  13.5
# 3648 1990-12-30  15.7
# 3649 1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df3.groupby('Date')['Temp'].mean()
# Out:
# Date
# 1981-01-01    20.7
# 1981-01-02    17.9
# 1981-01-03    18.8
# 1981-01-04    14.6
# 1981-01-05    15.8
#               ...
# 1990-12-27    14.0
# 1990-12-28    13.6
# 1990-12-29    13.5
# 1990-12-30    15.7
# 1990-12-31    13.0
# Name: Temp, Length: 3650, dtype: float64

# %%
df3.groupby('Date')['Temp'].mean().plot()
